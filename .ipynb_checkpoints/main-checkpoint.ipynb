# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import sys
from keras.layers.normalization import BatchNormalization
import pandas as pd

# %%
## training圖片顯示
img = plt.imread('train/0_3.jpg')
img.shape
plt.imshow(img)

# %%
## 對training data 分類

# %%
path = "train"
dirs = os.listdir(path) #顯示內部檔案名稱
train_data_shape = len(dirs) #訓練資料筆數

# %%
## 將檔案名稱變為list
aa = []
for file in dirs:
     aa.append(file)
#print(aa)

# %%
## 抓取list的字串
temp_id = []
temp_cat = []
for j in range(train_data_shape):
    b = aa[j].split('.') #先根據點先切開
    c = b[0].split('_') #再根據底線切開
    temp_id.append(c[0]) #抓取檔案id
    temp_cat.append(c[1]) #抓取檔案分類

# %%
#定義若分類是0,1,2,3則將圖片分類到所屬的檔案

# %%
#建立traning資料集
path = './training'
os.makedirs(path)

# %%
for k in range(4):
    path = './training/'+str(k)
    os.makedirs(path)

# %%
for i in range(train_data_shape):
    if (temp_cat[i] == '0'):
        img = plt.imread('train/'+ str(temp_id[i]) + '_0.jpg')
        cv2.imwrite('training/0/'+str(i)+'.jpg',cv2.cvtColor(img, cv2.COLOR_RGB2BGR)) #plt跟cv2的channel不同
    elif (temp_cat[i] == '1'):
        img = plt.imread('train/'+str(temp_id[i]) + '_1.jpg')
        cv2.imwrite('training/1/'+str(i)+'.jpg',cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
    elif (temp_cat[i] == '2'):
        img = plt.imread('train/'+ str(temp_id[i]) + '_2.jpg')
        cv2.imwrite('training/2/'+str(i)+'.jpg',cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
    else:
        img = plt.imread('train/'+str(temp_id[i]) + '_3.jpg')
        cv2.imwrite('training/3/'+str(temp_id[i])+'.jpg',cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

# %%
#建立模型
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout

# %%
model = Sequential(name = 'model3')
model.add(Conv2D(filters = 32,kernel_size = (3,3),input_shape = (64,64,3),padding='same',activation='relu'))
model.add(Conv2D(filters = 32,kernel_size = (3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.3))
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding='same',activation='relu'))
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size  = (2,2)))
model.add(Dropout(0.3))
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding='same',activation='relu'))
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size  = (2,2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(units = 128,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(units = 4,activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "model3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 664,996
# Trainable params: 664,676
# Non-trainable params: 320
# _________________________________________________________________

# %%
#產生器
from keras.preprocessing.image import ImageDataGenerator

# %%
#影像增強
#rotation_range在角度(0,15)中隨機旋轉
#width_shift_range=0.1,height_shift_range=0.1水平移動或垂直移動
#zoom_range長或寬進行放大
#horizontal_flip = True隨機對圖片進行水平翻轉
train_datagen = ImageDataGenerator(rescale = 1./255,rotation_range=20,shear_range = 0.2,zoom_range = 0.2,
                                   horizontal_flip = True,width_shift_range=0.1,height_shift_range=0.1,
                                   validation_split=0.2)
# train_datagen = ImageDataGenerator(vertical_flip=True)
training_set = train_datagen.flow_from_directory('training/',target_size=(64,64),color_mode="rgb",batch_size=15,class_mode='categorical')
# Out:
# Found 542 images belonging to 4 classes.

# %%
#影像增強例子

# %%
# from keras.preprocessing.image import img_to_array
# data = img_to_array(img)
# samples = np.expand_dims(data, axis=0)
# samples.astype('float32')
# Out:
# array([[[[ 20.,  11.,   6.],
#          [ 21.,  12.,   5.],
#          [ 22.,  13.,   6.],
#          ...,
#          [ 43.,  29.,  16.],
#          [ 43.,  29.,  18.],
#          [ 43.,  29.,  18.]],
#
#         [[ 20.,  11.,   6.],
#          [ 20.,  11.,   4.],
#          [ 22.,  13.,   6.],
#          ...,
#          [ 44.,  30.,  17.],
#          [ 43.,  29.,  18.],
#          [ 43.,  29.,  18.]],
#
#         [[ 19.,  10.,   5.],
#          [ 20.,  11.,   4.],
#          [ 21.,  12.,   5.],
#          ...,
#          [ 45.,  29.,  16.],
#          [ 43.,  29.,  16.],
#          [ 43.,  29.,  18.]],
#
#         ...,
#
#         [[112., 118., 114.],
#          [113., 119., 115.],
#          [116., 122., 118.],
#          ...,
#          [ 49.,  39.,  37.],
#          [ 49.,  39.,  37.],
#          [ 49.,  39.,  37.]],
#
#         [[115., 121., 117.],
#          [115., 121., 117.],
#          [119., 125., 121.],
#          ...,
#          [ 50.,  40.,  38.],
#          [ 50.,  40.,  38.],
#          [ 50.,  40.,  38.]],
#
#         [[116., 122., 118.],
#          [116., 122., 118.],
#          [120., 126., 122.],
#          ...,
#          [ 50.,  40.,  38.],
#          [ 50.,  40.,  38.],
#          [ 50.,  40.,  38.]]]], dtype=float32)

# %%
# datagen = ImageDataGenerator(rotation_range=15,shear_range = 0.2,zoom_range = 0.2,
# horizontal_flip = True,width_shift_range=0.1,height_shift_range=0.1)
# it = datagen.flow(samples, batch_size=1)

# for i in range(9):
#     plt.subplot(331 + i)
#     batch = it.next()
#     image = batch[0].astype('uint32')
#     plt.imshow(image)
# plt.show()

# %%
#validation geneator
validation_set = train_datagen.flow_from_directory('training/',target_size=(64,64),color_mode="rgb",batch_size=15,class_mode='categorical',subset='validation')
# Out:
# Found 107 images belonging to 4 classes.

# %%
#配適模型

# %%
history = model.fit_generator(
    training_set,
    steps_per_epoch=435//15,
    epochs=50,
    validation_data=validation_set,
    validation_steps=107//15)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 15s 504ms/step - loss: 2.5086 - accuracy: 0.3981 - val_loss: 1.7590 - val_accuracy: 0.2762
# Epoch 2/50
# 29/29 [==============================] - 13s 435ms/step - loss: 1.1766 - accuracy: 0.5284 - val_loss: 2.6327 - val_accuracy: 0.2826
# Epoch 3/50
# 29/29 [==============================] - 13s 443ms/step - loss: 1.0802 - accuracy: 0.4989 - val_loss: 3.3034 - val_accuracy: 0.1957
# Epoch 4/50
# 29/29 [==============================] - 12s 431ms/step - loss: 1.0418 - accuracy: 0.5308 - val_loss: 1.8770 - val_accuracy: 0.3152
# Epoch 5/50
# 29/29 [==============================] - 12s 428ms/step - loss: 0.9611 - accuracy: 0.5261 - val_loss: 4.9195 - val_accuracy: 0.3696
# Epoch 6/50
# 29/29 [==============================] - 13s 437ms/step - loss: 1.0367 - accuracy: 0.5569 - val_loss: 1.8854 - val_accuracy: 0.3913
# Epoch 7/50
# 29/29 [==============================] - 13s 437ms/step - loss: 0.9323 - accuracy: 0.5655 - val_loss: 1.6207 - val_accuracy: 0.3478
# Epoch 8/50
# 29/29 [==============================] - 12s 424ms/step - loss: 0.9831 - accuracy: 0.6066 - val_loss: 1.8926 - val_accuracy: 0.3043
# Epoch 9/50
# 29/29 [==============================] - 12s 427ms/step - loss: 0.9564 - accuracy: 0.5379 - val_loss: 2.2993 - val_accuracy: 0.2476
# Epoch 10/50
    plt.plot(history.history['loss'],color='b',label= 'training loss')
    plt.plot(history.history['val_accuracy'],color='r',label = 'val loss')
    plt.ylabel('loss')
    plt.legend(loc = 'upper right')
def plot_hist_acc(history):
    plt.plot(history.history['accuracy'],color='b',label= 'training acc')
    plt.plot(history.history['val_accuracy'],color='r',label = 'val acc')
   # plt.ylim(0.2,1.0)
    plt.ylabel('accracy')
    plt.legend(loc = 'lower right')

# %%
plot_hist_loss(history)

# %%
plot_hist_acc(history)

# %%
#模型權數儲存
model.save('model3.h5')
model.save_weights("model3.weight")

# %%
#測試資料集

# %%
# test_filenames = os.listdir("test")
# test_df = pd.DataFrame({
#     'filename': test_filenames
# })
# nb_samples = test_df.shape[0]

# %%
#testing generator
# test_gen = ImageDataGenerator(rescale=1./255)
# test_set = test_gen.flow_from_dataframe(
#     test_df, 
#     "test/", 
#     x_col='filename',
#     y_col=None,
#     class_mode=None,
#     target_size=(64,64),
#     color_mode="rgb",
#     batch_size=1,
#     shuffle=False
# )
# Out:
# Found 96 validated image filenames.

# %%
## predict
# predict = model.predict_generator(test_set, steps=np.ceil(nb_samples))
# predict
# Out:
# array([[6.21761210e-05, 2.17735942e-06, 3.36053967e-02, 9.66330290e-01],
#        [1.55818896e-08, 3.17290361e-11, 2.65872339e-04, 9.99734104e-01],
#        [1.41666655e-03, 8.37402622e-05, 6.20796323e-01, 3.77703339e-01],
#        [4.73020375e-02, 8.18378747e-01, 1.32152900e-01, 2.16629566e-03],
#        [8.74263421e-03, 8.41740131e-01, 1.48509383e-01, 1.00784458e-03],
#        [5.27597922e-06, 5.79884472e-05, 9.74991679e-01, 2.49450542e-02],
#        [1.16902113e-01, 6.37916446e-01, 2.34000996e-01, 1.11804120e-02],
#        [5.44808917e-02, 1.87530711e-01, 7.20605671e-01, 3.73827480e-02],
#        [1.55544525e-03, 5.30964792e-01, 4.62227941e-01, 5.25186118e-03],
#        [6.18437582e-07, 1.27087906e-03, 9.94901896e-01, 3.82657233e-03],
#        [1.52764231e-01, 5.40807992e-02, 3.77042979e-01, 4.16112036e-01],
#        [4.62731036e-13, 1.00000000e+00, 5.15281231e-13, 8.48170321e-18],
#        [9.05686524e-03, 8.17960620e-01, 1.69779480e-01, 3.20302066e-03],
#        [1.37571635e-13, 1.00000000e+00, 5.81783536e-13, 3.09412348e-16],
#        [3.26855574e-03, 2.86498010e-01, 4.89064306e-01, 2.21169144e-01],
#        [9.24639821e-01, 3.15186866e-02, 1.18346661e-02, 3.20068039e-02],
#        [4.97140593e-11, 1.00000000e+00, 1.31489042e-09, 1.82290943e-14],
#        [1.87424123e-01, 4.25020784e-01, 3.47166538e-01, 4.03885320e-02],
#        [1.48136030e-06, 2.83454842e-08, 2.53076805e-03, 9.97467756e-01],
#        [1.14412270e-01, 8.09209347e-01, 7.49831572e-02, 1.39525114e-03],
#        [2.30203688e-04, 6.97319210e-02, 7.09750831e-01, 2.20287055e-01],
#        [1.31321540e-02, 7.20455110e-01, 2.60270715e-01, 6.14209240e-03],
#        [8.45374167e-02, 8.27147961e-01, 8.78985897e-02, 4.15996008e-04],
#        [5.44603696e-13, 1.00000000e+00, 6.49051125e-13, 1.73970178e-17],
#        [8.39585721e-01, 2.14644591e-03, 5.81097230e-02, 1.00158043e-01],
#        [8.68662293e-13, 1.00000000e+00, 6.58938182e-12, 8.70526465e-17],
#        [1.02457115e-02, 4.30733245e-03, 2.65129715e-01, 7.20317185e-01],
#        [4.31415379e-01, 2.54724827e-03, 2.20701247e-02, 5.43967247e-01],
#        [1.15684979e-11, 1.00000000e+00, 8.68348449e-11, 2.16531903e-15],
#        [7.28481030e-03, 5.57457954e-02, 7.70328760e-01, 1.66640639e-01],
#        [7.12169427e-03, 3.58798876e-02, 7.07497835e-01, 2.49500543e-01],
#        [8.76879506e-03, 5.29831304e-05, 4.10267562e-02, 9.50151443e-01],
#        [9.99162793e-01, 5.34445397e-04, 1.31820445e-04, 1.70968953e-04],
#        [3.75458616e-13, 1.00000000e+00, 2.82193214e-12, 3.94195528e-16],
#        [4.82056104e-02, 6.06853008e-01, 3.13855171e-01, 3.10862400e-02],
#        [7.62033451e-04, 8.17588841e-07, 1.08700115e-02, 9.88367140e-01],
#        [7.23684134e-05, 3.18280087e-08, 2.26960448e-03, 9.97658014e-01],
#        [8.38674679e-02, 6.44774199e-01, 2.64974654e-01, 6.38362672e-03],
#        [6.35235012e-01, 2.54824641e-04, 4.24423767e-03, 3.60265970e-01],
#        [1.70666859e-01, 6.72635257e-01, 1.50813326e-01, 5.88455517e-03],
#        [3.32614407e-02, 8.93526495e-01, 7.26226196e-02, 5.89425210e-04],
#        [3.21548532e-06, 1.66070205e-03, 9.12782311e-01, 8.55537578e-02],
#        [7.84973279e-02, 8.52529168e-01, 6.86299279e-02, 3.43650463e-04],
#        [1.18792080e-03, 6.47147223e-02, 8.39064002e-01, 9.50333551e-02],
#        [8.31028228e-05, 4.92878668e-02, 8.53653312e-01, 9.69757587e-02],
#        [2.15609908e-12, 1.00000000e+00, 5.35787560e-12, 1.26048707e-16],
#        [1.16782228e-09, 6.52243057e-16, 4.21574759e-06, 9.99995828e-01],
#        [7.69685302e-03, 9.60871518e-01, 3.14132683e-02, 1.84950241e-05],
#        [3.72255184e-02, 2.04841420e-02, 5.71840093e-04, 9.41718519e-01],
#        [8.26052055e-05, 1.02207525e-06, 1.47991739e-02, 9.85117197e-01],
#        [4.74436209e-03, 4.23327629e-06, 9.75703169e-03, 9.85494375e-01],
#        [3.36874597e-04, 3.51880037e-04, 5.16500950e-01, 4.82810259e-01],
#        [2.36080028e-03, 3.33435391e-03, 1.84265688e-01, 8.10039103e-01],
#        [1.18752499e-11, 1.00000000e+00, 1.22273774e-10, 1.00495610e-15],
#        [8.67520557e-15, 1.00000000e+00, 1.56628521e-13, 1.23188394e-17],
#        [2.90082730e-02, 1.52145699e-02, 2.22972170e-01, 7.32805014e-01],
#        [1.31180184e-03, 4.46067721e-01, 5.49189389e-01, 3.43116373e-03],
#        [9.97774065e-01, 1.52535635e-04, 1.49898362e-04, 1.92358717e-03]],
#       dtype=float32)

# %%
test_df['category'] = np.argmax(predict, axis=-1)
test_df['category']
# Out:
# 0     3
# 1     3
# 2     2
# 3     1
# 4     1
#      ..
# 91    1
# 92    1
# 93    3
# 94    2
# 95    0
# Name: category, Length: 96, dtype: int64

# %%
## output the results
# result = './outcome.csv'
# dataframe_sample = pd.DataFrame.from_dict(test_df)
# dataframe_sample.to_csv(result,index=False)
